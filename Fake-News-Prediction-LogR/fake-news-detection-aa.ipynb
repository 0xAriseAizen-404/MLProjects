# %% [markdown]
# # https://www.kaggle.com/datasets/jainpooja/fake-news-detection/code

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import kagglehub
# Out:
# /kaggle/input/datasets/jainpooja/fake-news-detection/True.csv
# /kaggle/input/datasets/jainpooja/fake-news-detection/Fake.csv

# %%
print(os.getcwd())
# Out:
# /kaggle/working

# %%
df_fake = pd.read_csv("../input/datasets/jainpooja/fake-news-detection/Fake.csv")
df_true = pd.read_csv("../input/datasets/jainpooja/fake-news-detection/True.csv")

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake["class"] = 0
df_true["class"] = 1

# %%
df_fake.shape, df_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
# Removing last 10 rows for manual testing
df_fake_manual_testing = df_fake.tail(10)
for i in range(1, 11):
    df_fake.drop([(df_fake.shape[0] - i)], axis = 0, inplace = True)
    
    
df_true_manual_testing = df_true.tail(10)
for i in range(1, 11):
    df_true.drop([(df_true.shape[0] - i)], axis = 0, inplace = True)

# %%
df_fake.shape, df_true.shape
# Out:
# ((23471, 5), (21407, 5))

# %%
df_fake_manual_testing.reset_index(drop=True, inplace=True)
df_true_manual_testing.reset_index(drop=True, inplace=True)

# %%
df_true_manual_testing
# Out:
#                                                title  \
# 0  Mata Pires, owner of embattled Brazil builder ...
# 1  U.S., North Korea clash at U.N. forum over nuc...
# 2  U.S., North Korea clash at U.N. arms forum on ...
# 3  Headless torso could belong to submarine journ...
# 4  North Korea shipments to Syria chemical arms a...
# 5  'Fully committed' NATO backs new U.S. approach...
# 6  LexisNexis withdrew two products from Chinese ...
# 7  Minsk cultural hub becomes haven from authorities
# 8  Vatican upbeat on possibility of Pope Francis ...
# 9  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                 text    subject  \
# 0  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 1  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 2  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 3  COPENHAGEN (Reuters) - Danish police said on T...  worldnews
# 4  UNITED NATIONS (Reuters) - Two North Korean sh...  worldnews
# 5  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 6  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 7  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 8  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 9  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                date  class
# 0  August 22, 2017       1
# 1  August 22, 2017       1
# 2  August 22, 2017       1
# 3  August 22, 2017       1
# 4  August 21, 2017       1
# 5  August 22, 2017       1
# 6  August 22, 2017       1
# 7  August 22, 2017       1
# 8  August 22, 2017       1
# 9  August 22, 2017       1

# %%
df_manual_testing = pd.concat([df_fake_manual_testing, df_true_manual_testing], axis = 0)
# df_manual_testing.reset_index(drop=True, inplace=True)
df_manual_testing.to_csv("manual_testing.csv")

# %%
df_merge = pd.concat([df_fake, df_true], axis=0 )
df_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
# 9  Just when you might have thought we d get a br...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0
# 5  December 25, 2017      0
# 6  December 23, 2017      0
# 7  December 23, 2017      0
# 8  December 22, 2017      0
# 9  December 21, 2017      0

# %%
df_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
df = df_merge.drop(["title", "subject","date"], axis = 1)
df.shape
# Out:
# (44878, 2)

# %%
df.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
df = df.sample(frac = 1)
df.shape
# Out:
# (44878, 2)

# %%
df.head(10)
# Out:
#                                                     text  class
# 14138  The breaking point is fast approaching in a di...      0
# 17011  BEIJING (Reuters) - Late U.S. President Abraha...      1
# 3337   On Monday, the election of Donald Trump became...      0
# 12008  JERUSALEM (Reuters) - The Israeli military sai...      1
# 20767  ANKARA (Reuters) - Turkey s economy minister s...      1
# 6771   BEIJING (Reuters) - Those who seek to damage t...      1
# 20590  What if 20 Million Illegal Aliens Vacated Amer...      0
# 3737   WASHINGTON (Reuters) - President Donald Trump ...      1
# 19779  BEIRUT (Reuters) - The Deir al-Zor military ai...      1
# 11505                                                         0

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(5)
# Out:
#                                                 text  class
# 0  The breaking point is fast approaching in a di...      0
# 1  BEIJING (Reuters) - Late U.S. President Abraha...      1
# 2  On Monday, the election of Donald Trump became...      0
# 3  JERUSALEM (Reuters) - The Israeli military sai...      1
# 4  ANKARA (Reuters) - Turkey s economy minister s...      1

# %%
def process_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_16/3571241116.py:3: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]', '', text)
# /tmp/ipykernel_16/3571241116.py:5: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+', '', text)
# /tmp/ipykernel_16/3571241116.py:9: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub('\w*\d\w*', '', text)

# %%
df["text"] = df["text"].apply(process_text)

# %%
x = df["text"]
y = df["class"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)
LR.score(xv_test, y_test)
# Out:
# 0.984313725490196

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5845
#            1       0.98      0.98      0.98      5375
#
#     accuracy                           0.98     11220
#    macro avg       0.98      0.98      0.98     11220
# weighted avg       0.98      0.98      0.98     11220

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)
DT.score(xv_test, y_test)
# Out:
# 0.9946524064171123

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5845
#            1       1.00      0.99      0.99      5375
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(random_state=0)
RFC.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rfc = RFC.predict(xv_test)
RFC.score(xv_test, y_test)
# Out:
# 0.9868983957219252

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5845
#            1       0.99      0.98      0.99      5375
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# ### Manual Testing

# %%
def output_lable(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(process_text) 
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_RFC = RFC.predict(new_xv_test)

    return print("\n\nLR Prediction: {} \nDT Prediction: {} \nRFC Prediction: {}".format(output_lable(pred_LR[0]),
                                                                                                              output_lable(pred_DT[0]), 
                                                                                                              output_lable(pred_RFC[0])))

# %%
df_manual_testing = df_manual_testing.sample(frac = 1)
df_manual_testing.reset_index(drop=True, inplace=True)

# %%
news = df_manual_testing.iloc[4, :]
manual_testing(news.text), news["class"]
# Out:
# LR Prediction: Not A Fake News
# DT Prediction: Not A Fake News
# RFC Prediction: Not A Fake News
# (None, np.int64(1))
